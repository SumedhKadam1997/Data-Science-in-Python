# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
df = pd.read_csv("C:\\Users\\uxoriousghost\\Python Machine Learning\\Datasets\\country_vaccinations.csv")

# %%
df
# Out:
#        country iso_code        date  total_vaccinations  people_vaccinated  \
# 0      Albania      ALB  2021-01-10                 0.0                0.0
# 1      Albania      ALB  2021-01-11                 NaN                NaN
# 2      Albania      ALB  2021-01-12               128.0              128.0
# 3      Albania      ALB  2021-01-13               188.0              188.0
# 4      Albania      ALB  2021-01-14               266.0              266.0
# ...        ...      ...         ...                 ...                ...
# 4430  Zimbabwe      ZWE  2021-02-23              4041.0             4041.0
# 4431  Zimbabwe      ZWE  2021-02-24              7872.0             7872.0
# 4432  Zimbabwe      ZWE  2021-02-25             11007.0            11007.0
# 4433  Zimbabwe      ZWE  2021-02-26             12579.0            12579.0
# 4434  Zimbabwe      ZWE  2021-02-27             15705.0            15705.0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4435 entries, 0 to 4434
# Data columns (total 15 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   country                              4435 non-null   object
#  1   iso_code                             4131 non-null   object
#  2   date                                 4435 non-null   object
#  3   total_vaccinations                   2916 non-null   float64
#  4   people_vaccinated                    2483 non-null   float64
#  5   people_fully_vaccinated              1662 non-null   float64
#  6   daily_vaccinations_raw               2467 non-null   float64
#  7   daily_vaccinations                   4281 non-null   float64
#  8   total_vaccinations_per_hundred       2916 non-null   float64
#  9   people_vaccinated_per_hundred        2483 non-null   float64
#  10  people_fully_vaccinated_per_hundred  1662 non-null   float64
# ...

# %%
df["date"] = pd.to_datetime(df["date"], format = '%Y-%m-%d')
df = df.replace([np.inf, -np.inf], np.nan)
df = df.fillna(0)
df
# Out:
#        country iso_code       date  total_vaccinations  people_vaccinated  \
# 0      Albania      ALB 2021-01-10                 0.0                0.0
# 1      Albania      ALB 2021-01-11                 0.0                0.0
# 2      Albania      ALB 2021-01-12               128.0              128.0
# 3      Albania      ALB 2021-01-13               188.0              188.0
# 4      Albania      ALB 2021-01-14               266.0              266.0
# ...        ...      ...        ...                 ...                ...
# 4430  Zimbabwe      ZWE 2021-02-23              4041.0             4041.0
# 4431  Zimbabwe      ZWE 2021-02-24              7872.0             7872.0
# 4432  Zimbabwe      ZWE 2021-02-25             11007.0            11007.0
# 4433  Zimbabwe      ZWE 2021-02-26             12579.0            12579.0
# 4434  Zimbabwe      ZWE 2021-02-27             15705.0            15705.0
#
#       people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# ...

# %%
display(df[df["vaccines"]=="Pfizer/BioNTech"])
# Out:
#                        country iso_code       date  total_vaccinations  \
# 0                      Albania      ALB 2021-01-10                 0.0
# 1                      Albania      ALB 2021-01-11                 0.0
# 2                      Albania      ALB 2021-01-12               128.0
# 3                      Albania      ALB 2021-01-13               188.0
# 4                      Albania      ALB 2021-01-14               266.0
# ...                        ...      ...        ...                 ...
# 4135  Turks and Caicos Islands      TCA 2021-02-04                 0.0
# 4136  Turks and Caicos Islands      TCA 2021-02-05                 0.0
# 4137  Turks and Caicos Islands      TCA 2021-02-06                 0.0
# 4138  Turks and Caicos Islands      TCA 2021-02-07                 0.0
# 4139  Turks and Caicos Islands      TCA 2021-02-08              6433.0
#
#       people_vaccinated  people_fully_vaccinated  daily_vaccinations_raw  \
# ...

# %%
display(df[df["vaccines"]=="Sinopharm/Beijing"])
# Out:
#        country iso_code       date  total_vaccinations  people_vaccinated  \
# 642   Cambodia      KHM 2021-02-09                 0.0                0.0
# 643   Cambodia      KHM 2021-02-10              1492.0             1492.0
# 644   Cambodia      KHM 2021-02-11                 0.0                0.0
# 645   Cambodia      KHM 2021-02-12                 0.0                0.0
# 646   Cambodia      KHM 2021-02-13                 0.0                0.0
# ...        ...      ...        ...                 ...                ...
# 4430  Zimbabwe      ZWE 2021-02-23              4041.0             4041.0
# 4431  Zimbabwe      ZWE 2021-02-24              7872.0             7872.0
# 4432  Zimbabwe      ZWE 2021-02-25             11007.0            11007.0
# 4433  Zimbabwe      ZWE 2021-02-26             12579.0            12579.0
# 4434  Zimbabwe      ZWE 2021-02-27             15705.0            15705.0
#
#       people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# ...

# %%
display(df[df["vaccines"]=='Covaxin, Oxford/AstraZeneca'])
# Out:
#      country iso_code       date  total_vaccinations  people_vaccinated  \
# 1891   India      IND 2021-01-15                 0.0                0.0
# 1892   India      IND 2021-01-16            191181.0           191181.0
# 1893   India      IND 2021-01-17            224301.0           224301.0
# 1894   India      IND 2021-01-18            454049.0           454049.0
# 1895   India      IND 2021-01-19            674835.0           674835.0
# 1896   India      IND 2021-01-20            806484.0           806484.0
# 1897   India      IND 2021-01-21           1043534.0          1043534.0
# 1898   India      IND 2021-01-22           1390592.0          1390592.0
# 1899   India      IND 2021-01-23           1582201.0          1582201.0
# 1900   India      IND 2021-01-24           1615504.0          1615504.0
# 1901   India      IND 2021-01-25           2023809.0          2023809.0
# 1902   India      IND 2021-01-26           2029480.0          2029480.0
# ...

# %%
df["vaccines"].unique()
# Out:
# array(['Pfizer/BioNTech', 'Sputnik V', 'Oxford/AstraZeneca',
#        'Moderna, Oxford/AstraZeneca, Pfizer/BioNTech',
#        'Oxford/AstraZeneca, Sputnik V',
#        'Pfizer/BioNTech, Sinopharm/Beijing, Sputnik V',
#        'Oxford/AstraZeneca, Sinovac', 'Sinopharm/Beijing',
#        'Moderna, Pfizer/BioNTech', 'Pfizer/BioNTech, Sinovac',
#        'Sinopharm/Beijing, Sinopharm/Wuhan, Sinovac',
#        'Oxford/AstraZeneca, Pfizer/BioNTech',
#        'Moderna, Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing, Sputnik V',
#        'Covaxin, Oxford/AstraZeneca', 'Sinovac',
#        'Oxford/AstraZeneca, Pfizer/BioNTech, Sputnik V',
#        'Oxford/AstraZeneca, Sinopharm/Beijing',
#        'Oxford/AstraZeneca, Sinopharm/Beijing, Sputnik V',
#        'Johnson&Johnson',
#        'Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing, Sinopharm/Wuhan, Sputnik V'],
#       dtype=object)

# %%
display(df[df["vaccines"]=="Pfizer/BioNTech"].sort_values(by="total_vaccinations", ascending= False).head(10).style.background_gradient(cmap="CMRmap_r"))
# Out:
# <style  type="text/css" >
# #T_e4b6b2d2_7c06_11eb_aee1_283a4d1f4d42row0_col3,#T_e4b6b2d2_7c06_11eb_aee1_283a4d1f4d42row0_col7,#T_e4b6b2d2_7c06_11eb_aee1_283a4d1f4d42row8_col4,#T_e4b6b2d2_7c06_11eb_aee1_283a4d1f4d42row8_col5,#T_e4b6b2d2_7c06_11eb_aee1_283a4d1f4d42row8_col6,#T_e4b6b2d2_7c06_11eb_aee1_283a4d1f4d42row8_col8,#T_e4b6b2d2_7c06_11eb_aee1_283a4d1f4d42row8_col9,#T_e4b6b2d2_7c06_11eb_aee1_283a4d1f4d42row8_col10,#T_e4b6b2d2_7c06_11eb_aee1_283a4d1f4d42row8_col11{
#             background-color:  #000000;
#             color:  #f1f1f1;
# ...

# %%
display(df[df["vaccines"]=="Sputnik V"].sort_values(by="total_vaccinations", ascending= False).head(10).style.background_gradient(cmap="CMRmap_r"))
# Out:
# <style  type="text/css" >
# #T_142456d6_7c07_11eb_9ebc_283a4d1f4d42row0_col3,#T_142456d6_7c07_11eb_9ebc_283a4d1f4d42row0_col4,#T_142456d6_7c07_11eb_9ebc_283a4d1f4d42row0_col5,#T_142456d6_7c07_11eb_9ebc_283a4d1f4d42row0_col7,#T_142456d6_7c07_11eb_9ebc_283a4d1f4d42row0_col8,#T_142456d6_7c07_11eb_9ebc_283a4d1f4d42row0_col10,#T_142456d6_7c07_11eb_9ebc_283a4d1f4d42row2_col6,#T_142456d6_7c07_11eb_9ebc_283a4d1f4d42row2_col9,#T_142456d6_7c07_11eb_9ebc_283a4d1f4d42row2_col11{
#             background-color:  #000000;
#             color:  #f1f1f1;
# ...

# %%
display(df[df["vaccines"]=="Covaxin, Oxford/AstraZeneca"].sort_values(by="total_vaccinations", ascending= False).head(10).style.background_gradient(cmap="CMRmap_r"))
# Out:
# <style  type="text/css" >
# #T_456b9039_7c07_11eb_8106_283a4d1f4d42row0_col3,#T_456b9039_7c07_11eb_8106_283a4d1f4d42row0_col4,#T_456b9039_7c07_11eb_8106_283a4d1f4d42row0_col5,#T_456b9039_7c07_11eb_8106_283a4d1f4d42row0_col7,#T_456b9039_7c07_11eb_8106_283a4d1f4d42row0_col8,#T_456b9039_7c07_11eb_8106_283a4d1f4d42row0_col9,#T_456b9039_7c07_11eb_8106_283a4d1f4d42row0_col10,#T_456b9039_7c07_11eb_8106_283a4d1f4d42row0_col11,#T_456b9039_7c07_11eb_8106_283a4d1f4d42row2_col6{
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }#T_456b9039_7c07_11eb_8106_283a4d1f4d42row0_col6{
#             background-color:  #ea3d38;
#             color:  #f1f1f1;
#         }#T_456b9039_7c07_11eb_8106_283a4d1f4d42row1_col3{
#             background-color:  #222270;
#             color:  #f1f1f1;
#         }#T_456b9039_7c07_11eb_8106_283a4d1f4d42row1_col4{
#             background-color:  #1e1e64;
#             color:  #f1f1f1;
# ...

# %%
display(df[df["vaccines"]=="Oxford/AstraZeneca"].sort_values(by="total_vaccinations", ascending= False).head(10).style.background_gradient(cmap="CMRmap_r"))
# Out:
# <style  type="text/css" >
# #T_28f6442c_7c07_11eb_b68c_283a4d1f4d42row0_col3,#T_28f6442c_7c07_11eb_b68c_283a4d1f4d42row0_col4,#T_28f6442c_7c07_11eb_b68c_283a4d1f4d42row0_col8,#T_28f6442c_7c07_11eb_b68c_283a4d1f4d42row0_col9,#T_28f6442c_7c07_11eb_b68c_283a4d1f4d42row6_col6,#T_28f6442c_7c07_11eb_b68c_283a4d1f4d42row6_col7,#T_28f6442c_7c07_11eb_b68c_283a4d1f4d42row6_col11{
#             background-color:  #000000;
#             color:  #f1f1f1;
# ...

# %% [markdown]
# # Which Countries have vaccinated more.

# %%
Country = pd.DataFrame(list(zip(df.country.value_counts().index,df.country.value_counts())), columns=['country','count'], index=None)

# %%
sns.factorplot(x="count", y="country",  data = Country , kind = "bar", size = 10, aspect = 1.90, palette = 'PuBuGn_d')
# Out:
# C:\Users\uxoriousghost\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\seaborn\categorical.py:3704: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\Users\uxoriousghost\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\seaborn\categorical.py:3710: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
df["day"] = df["date"].dt.day
df["month"] =df["date"].dt.month
df["year"] = df["date"].dt.year

# %%
df
# Out:
#        country iso_code       date  total_vaccinations  people_vaccinated  \
# 0      Albania      ALB 2021-01-10                 0.0                0.0
# 1      Albania      ALB 2021-01-11                 0.0                0.0
# 2      Albania      ALB 2021-01-12               128.0              128.0
# 3      Albania      ALB 2021-01-13               188.0              188.0
# 4      Albania      ALB 2021-01-14               266.0              266.0
# ...        ...      ...        ...                 ...                ...
# 4430  Zimbabwe      ZWE 2021-02-23              4041.0             4041.0
# 4431  Zimbabwe      ZWE 2021-02-24              7872.0             7872.0
# 4432  Zimbabwe      ZWE 2021-02-25             11007.0            11007.0
# 4433  Zimbabwe      ZWE 2021-02-26             12579.0            12579.0
# 4434  Zimbabwe      ZWE 2021-02-27             15705.0            15705.0
#
#       people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# ...

# %%
fig, ax = plt.subplots(figsize = (15, 6))

sns.lineplot(df["month"], df["people_vaccinated"], hue = df["day"], palette = "mako")

ax.set_title("Seasonal people_vaccinated")
ax.set_xlabel("month")
ax.set_ylabel("people_vaccinated")
# Out:
# C:\Users\uxoriousghost\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0, 0.5, 'people_vaccinated')

# %%
fig, ax = plt.subplots(figsize = (15, 6))

sns.lineplot(df["month"], df["people_fully_vaccinated"], hue = df["day"], palette = "mako")

ax.set_title("Seasonal people_vaccinated")
ax.set_xlabel("month")
ax.set_ylabel("people_fully_vaccinated")
# Out:
# C:\Users\uxoriousghost\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0, 0.5, 'people_fully_vaccinated')

# %%
fig, ax = plt.subplots(figsize = (15, 6))

sns.lineplot(df["month"], df["daily_vaccinations_raw"], hue = df["day"], palette = "mako")

ax.set_title("Seasonal people_vaccinated")
ax.set_xlabel("month")
ax.set_ylabel("daily_vaccinations_raw")
# Out:
# C:\Users\uxoriousghost\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0, 0.5, 'daily_vaccinations_raw')

# %%
ttl_people_vaccinated_per_hundred= df.sort_values(by='people_vaccinated_per_hundred', ascending=False)[:7000]
figure = plt.figure(figsize=(15,10))
sns.barplot(y=ttl_people_vaccinated_per_hundred.country, x=ttl_people_vaccinated_per_hundred.people_vaccinated_per_hundred)
plt.xticks()
plt.xlim(xmin=0.8)
plt.xlabel('people_vaccinated_per_hundred')
plt.ylabel('COUNTRY')
plt.title('Countplot of country by people_vaccinated_per_hundred')
plt.show()

# %%
ttl_daily_vaccinations_per_million= df.sort_values(by='daily_vaccinations_per_million', ascending=False)[:7000]
figure = plt.figure(figsize=(15,10))
sns.barplot(y=ttl_daily_vaccinations_per_million.country, x=ttl_daily_vaccinations_per_million.daily_vaccinations_per_million)
plt.xticks()
plt.xlim(xmin=0.8)
plt.xlabel('daily_vaccinations_per_million')
plt.ylabel('COUNTRY')
plt.title('Countplot of country by daily_vaccinations_per_million')
plt.show()

# %%
ttl_daily_vaccinations_per_million= df.sort_values(by='daily_vaccinations_per_million', ascending=False)[:7000]

# %%
ttl_daily_vaccinations_per_million
# Out:
#                country iso_code       date  total_vaccinations  \
# 1427  Falkland Islands      FLK 2021-02-09                 0.0
# 1432  Falkland Islands      FLK 2021-02-14                 0.0
# 1433  Falkland Islands      FLK 2021-02-15              1515.0
# 1431  Falkland Islands      FLK 2021-02-13                 0.0
# 1430  Falkland Islands      FLK 2021-02-12                 0.0
# ...                ...      ...        ...                 ...
# 4064            Turkey      TUR 2021-01-13                 0.0
# 1434           Finland      FIN 2020-12-31              1767.0
# 1425  Falkland Islands      FLK 2021-02-07                 0.0
# 1398    Faeroe Islands      FRO 2021-01-29              3994.0
# 0              Albania      ALB 2021-01-10                 0.0
#
#       people_vaccinated  people_fully_vaccinated  daily_vaccinations_raw  \
# 1427                0.0                      0.0                     0.0
# ...

# %%
display(df.groupby(['country','vaccines']).agg(["max",'mean',"min"]).style.background_gradient(cmap="CMRmap_r"))
# Out:
# <style  type="text/css" >
# ...
